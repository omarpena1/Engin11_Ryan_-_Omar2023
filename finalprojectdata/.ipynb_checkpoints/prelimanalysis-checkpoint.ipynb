# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = np.loadtxt('Spectrum_Etch_basement.csv', delimiter=",", skiprows=1)
data = np.delete(file, 0, 1)
plt.plot(data.sum(axis = 0))
plt.yscale("log")

# %%
datalist = [("Etch_Soda_JacobsBackground.csv", "Etch_basement.csv"), ("Etch_Soda_JacobsBackground.csv", "Jacobs_basement.csv"), 
           ("Etch_Soda_JacobsBackground.csv", "Soda_basement.csv"), ("EvansBackground.csv", "Evans_basement.csv"), 
           ("GladeBackground.csv", "Moffitt_basement.csv"), ("GladeBackground.csv", "Mainstacks.csv"), ("SocialsciencesBackground.csv", "Socialsciences_basement.csv"),
           ("underhillbackground.csv", "underhillbasement.csv"), ("unit2background.csv", "unit2basement.csv")]

# %%
for tup in datalist:
    print("Radiation",tup[1], tup[0], np.mean(pd.read_csv(tup[1])["Radiation (cps)"]) - np.mean(pd.read_csv(tup[0])["Radiation (cps)"]))
    print("Bismuth",tup[1], tup[0], np.mean(pd.read_csv(tup[1])["Radiation Bi (cps)"]) - np.mean(pd.read_csv(tup[0])["Radiation Bi (cps)"]))
    a = pd.read_csv(tup[0])
    b = pd.read_csv(tup[1])
    plt.figure()
    plt.hist(a["Radiation (cps)"], alpha = .75, label = "Outside")
    plt.hist(b["Radiation (cps)"], alpha = .75, label = "Inside")
    plt.xlabel("counts per second")
    plt.ylabel("frequency")
    plt.title("Radiation (cps)")
    plt.legend(loc="best")
    plt.show()
    plt.figure()
    plt.hist(a["Radiation Bi (cps)"], alpha = .75, label = "Outside")
    plt.hist(b["Radiation Bi (cps)"], alpha = .75, label = "Inside")
    plt.xlabel("counts per second")
    plt.ylabel("frequency")
    plt.title("Bismuth Radiation (cps)")
    plt.legend(loc="best")
    plt.show()
# Out:
# Radiation Etch_basement.csv Etch_Soda_JacobsBackground.csv 16.9936507936508
# Bismuth Etch_basement.csv Etch_Soda_JacobsBackground.csv 0.4888888888888888
# Radiation Jacobs_basement.csv Etch_Soda_JacobsBackground.csv -2.7567765567765647
# Bismuth Jacobs_basement.csv Etch_Soda_JacobsBackground.csv 0.32307692307692293
# Radiation Soda_basement.csv Etch_Soda_JacobsBackground.csv -20.61347708894879
# Bismuth Soda_basement.csv Etch_Soda_JacobsBackground.csv -0.26415094339622613
# Radiation Evans_basement.csv EvansBackground.csv -5.383614759224507
# Bismuth Evans_basement.csv EvansBackground.csv -0.24427767354596597
# Radiation Moffitt_basement.csv GladeBackground.csv 8.492959001782538
# Bismuth Moffitt_basement.csv GladeBackground.csv 0.459090909090909
# Radiation Mainstacks.csv GladeBackground.csv -9.334313725490198
# Bismuth Mainstacks.csv GladeBackground.csv -0.10555555555555562
# Radiation Socialsciences_basement.csv SocialsciencesBackground.csv 7.095238095238109
# Bismuth Socialsciences_basement.csv SocialsciencesBackground.csv 0.19809523809523766
# Radiation underhillbasement.csv underhillbackground.csv 1.368333333333318
# Bismuth underhillbasement.csv underhillbackground.csv 0.12166666666666703
# Radiation unit2basement.csv unit2background.csv -3.6012403100775323
# Bismuth unit2basement.csv unit2background.csv -0.06139534883720943

# %%
np.mean(pd.read_csv("etch30minute.csv")["Radiation Bi (cps)"])
# Out:
# 0.44160583941605874

# %%
np.mean(pd.read_csv("Etch_basement.csv")["Radiation Bi (cps)"])
# Out:
# 1.4888888888888887

# %%
file = np.loadtxt("Spectrum_moffitt30minute.csv", delimiter=",", skiprows=1)
data = np.delete(file, 0, 1)
plt.plot(data.sum(axis = 0))
plt.yscale("log")

# %%
file = np.loadtxt("Spectrum_outsidemoffitt30minute.csv", delimiter=",", skiprows=1)
data = np.delete(file, 0, 1)
plt.plot(data.sum(axis = 0))
plt.yscale("log")

# %%
file = np.loadtxt("etch30minutespectrum.csv", delimiter=",", skiprows=1)
data = np.delete(file, 0, 1)
plt.plot(data.sum(axis = 0))
plt.yscale("log")

# %%
file = np.loadtxt("Spectrum_outsideetcheverry30minute.csv", delimiter=",", skiprows=1)
data = np.delete(file, 0, 1)
plt.plot(data.sum(axis = 0))
plt.yscale("log")

# %%
b = pd.read_csv("etch30minute.csv")
a = pd.read_csv("outsideetcheverry30minute.csv")

# %%
plt.hist(a["Radiation (cps)"], alpha = .75, label = "Outside")
plt.hist(b["Radiation (cps)"], alpha = .75, label = "Inside")
plt.xlabel("counts per second")
plt.ylabel("frequency")
plt.title("Radiation (cps)")
plt.legend(loc="best")
plt.show()

# %%
plt.hist(a["Radiation Bi (cps)"], alpha = .75, label = "Outside")
plt.hist(b["Radiation Bi (cps)"], alpha = .75, label = "Inside")
plt.xlabel("counts per second")
plt.ylabel("frequency")
plt.title("Bismuth Radiation (cps)")
plt.legend(loc="best")
plt.show()

# %%
b = pd.read_csv("moffitt30minute.csv")
a = pd.read_csv("outsidemoffitt30minute.csv")

# %%
plt.hist(a["Radiation (cps)"], alpha = .75, label = "Outside")
plt.hist(b["Radiation (cps)"], alpha = .75, label = "Inside")
plt.xlabel("counts per second")
plt.ylabel("frequency")
plt.title("Radiation (cps)")
plt.legend(loc="best")
plt.show()

# %%
plt.hist(a["Radiation Bi (cps)"], alpha = .75, label = "Outside")
plt.hist(b["Radiation Bi (cps)"], alpha = .75, label = "Inside")
plt.xlabel("counts per second")
plt.ylabel("frequency")
plt.title("Bismuth Radiation (cps)")
plt.legend(loc="best")
plt.show()
