# %%
import pandas as pd

# %%
mergedata = pd.read_csv("mergedata.csv")

# %%
mergedata
# Out:
#            time  Concentration Units (Standard) PM 1.0  \
# 0    1676677883                                      0
# 1    1676677885                                      0
# 2    1676677886                                      0
# 3    1676677887                                      1
# 4    1676677888                                      1
# ..          ...                                    ...
# 295  1676678235                                      0
# 296  1676678236                                      1
# 297  1676678237                                      0
# 298  1676678239                                      0
# 299  1676678240                                      0
#
#      Concentration Units (Standard) PM 2.5  \
# 0                                        2
# 1                                        2
# 2                                        2
# 3                                        2
# 4                                        2
# ...

# %%
mergedata.plot(x = "time", y = "Concentration Units (Standard) PM 1.0")
# Out:
# <AxesSubplot:xlabel='time'>

# %%
mergedata.plot(x = "time", y = "Concentration Units (Standard) PM 2.5")
# Out:
# <AxesSubplot:xlabel='time'>

# %%
mergedata.plot(x = "time", y = "Concentration Units (Standard) PM 10.0")
# Out:
# <AxesSubplot:xlabel='time'>

# %%
mergedata.plot(x = "time", y = "temperature")
# Out:
# <AxesSubplot:xlabel='time'>

# %%
mergedata.plot(x = "time", y = "gas")
# Out:
# <AxesSubplot:xlabel='time'>

# %%
mergedata.plot(x = "time", y = "pressure")
# Out:
# <AxesSubplot:xlabel='time'>

# %%
mergedata.plot(x = "time", y = "humidity")
# Out:
# <AxesSubplot:xlabel='time'>

# %%
mergedata.plot(x = "time", y = "altitude")
# Out:
# <AxesSubplot:xlabel='time'>
